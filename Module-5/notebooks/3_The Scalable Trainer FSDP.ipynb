# %% [markdown]
# # The Scalable Trainer (FSDP)

# %% [markdown]
# ## Install Dependencies

# %%
# %pip install lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.9/827.9 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 27.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Model Code

# %%
# %%writefile model.py

import lightning as L
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, DataCollatorForLanguageModeling
from torch.optim import AdamW
from transformers import get_cosine_schedule_with_warmup
from datasets import load_dataset
from torch.utils.data import DataLoader
from lightning.pytorch.strategies import FSDPStrategy
from transformers.models.gpt2.modeling_gpt2 import GPT2Block

class BabyGPT(L.LightningModule):
    def __init__(self, model_name="TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T", lr=2e-4):
        super().__init__()
        self.save_hyperparameters()

        self.model = AutoModelForCausalLM.from_pretrained(model_name)
        self.model.gradient_checkpointing_enable()

    def forward(self, input_ids, attention_mask=None, labels=None):
        return self.model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )

    def training_step(self, batch, batch_idx):
        outputs = self(**batch)
        loss = outputs.loss

        self.log("train_loss", loss, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        outputs = self(**batch)
        val_loss = outputs.loss

        # Calculate Perplexity (The "Confusion" Score)
        # Loss is Logarithmic (e.g., 2.5). Perplexity is Linear (e.g., 12.1).
        # We convert by using exponent (e^loss)
        perplexity = torch.exp(val_loss)

        self.log("val_loss", val_loss, prog_bar=True)
        self.log("val_perplexity", perplexity, prog_bar=True)

        return val_loss

    def test_step(self, batch, batch_idx):
        outputs = self(**batch)
        test_loss = outputs.loss
        perplexity = torch.exp(test_loss)

        self.log("test_loss", test_loss, prog_bar=True)
        self.log("test_perplexity", perplexity, prog_bar=True)

        return test_loss

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=self.hparams.lr)
        total_steps = self.trainer.estimated_stepping_batches
        warmup_steps = int(total_steps * 0.1)
        scheduler = get_cosine_schedule_with_warmup(
            optimizer,
            num_warmup_steps=warmup_steps,
            num_training_steps=total_steps
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                # CRITICAL: We update the LR every 'step' (batch), not every 'epoch'.
                "interval": "step",
            }
        }

    def generate_text(self, tokenizer, prompt, max_new_tokens=50, temperature=0.7):
        inputs = tokenizer(prompt, return_tensors="pt").to(self.device)
        with torch.no_grad():
            outputs = self.model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=True,
                temperature=temperature,
                top_k=50,
                pad_token_id=tokenizer.eos_token_id
            )
        return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# Writing model.py

# %% [markdown]
# ## Data Code

# %%
# %%writefile data.py

import lightning as L
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, DataCollatorForLanguageModeling
from torch.optim import AdamW
from transformers import get_cosine_schedule_with_warmup
from datasets import load_dataset
from torch.utils.data import DataLoader
from lightning.pytorch.strategies import FSDPStrategy
from transformers.models.gpt2.modeling_gpt2 import GPT2Block

class WikiDataModule(L.LightningDataModule):
    def __init__(self, model_name="gpt2", batch_size=32, max_length=128):
        super().__init__()
        self.model_name = model_name
        self.batch_size = batch_size
        self.max_length = max_length

        # Performance Tip: Set num_workers to your CPU count to load data faster.
        self.num_workers = 6

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        # The fix we discussed earlier
        if self.tokenizer.pad_token is None:
            self.tokenizer.pad_token = self.tokenizer.eos_token

    def prepare_data(self):
        self.dataset = load_dataset("wikitext", "wikitext-103-raw-v1")

    def setup(self, stage=None):
        # 1. Load raw data
        dataset = load_dataset('wikitext', 'wikitext-2-raw-v1')

        # 2. Define the tokenizer logic
        def tokenize_function(examples):
            # We truncate here to ensure no sequence exceeds our max memory
            return self.tokenizer(
                examples["text"],
                truncation=True,
                max_length=self.max_length
            )

        # 3. Apply tokenization (Map)
        # We remove the 'text' column because the model only needs numbers (input_ids).
        tokenized_datasets = dataset.map(
            tokenize_function,
            batched=True,
            remove_columns=["text"]
        )

        # 4. Filter out empty sequences (this is the fix!)
        def filter_empty(example):
            return len(example["input_ids"]) > 0

        tokenized_datasets = tokenized_datasets.filter(filter_empty)

        # 5. Split for training phases
        if stage == 'fit' or stage is None:
            self.train_dataset = tokenized_datasets["train"]
            self.val_dataset = tokenized_datasets["validation"]

        if stage == 'test':
            self.test_dataset = tokenized_datasets["test"]

    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True, # Always shuffle training data!
            num_workers=self.num_workers,
            # This is where Dynamic Padding happens:
            collate_fn=DataCollatorForLanguageModeling(self.tokenizer, mlm=False),
            pin_memory=True # Speed boost for data transfer to GPU
        )

    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            collate_fn=DataCollatorForLanguageModeling(self.tokenizer, mlm=False),
            pin_memory=True
        )

    def test_dataloader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            collate_fn=DataCollatorForLanguageModeling(self.tokenizer, mlm=False),
            pin_memory=True
        )
# Out:
# Writing data.py

# %% [markdown]
# ## The Auto-Wrap Policy

# %%
# %%writefile train.py

import lightning as L
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, DataCollatorForLanguageModeling
from torch.optim import AdamW
from transformers import get_cosine_schedule_with_warmup
from datasets import load_dataset
from torch.utils.data import DataLoader
from lightning.pytorch.strategies import FSDPStrategy
from transformers.models.gpt2.modeling_gpt2 import GPT2Block
from model import BabyGPT
from data import WikiDataModule


def train_fsdp():
    fsdp_strategy = FSDPStrategy(
        auto_wrap_policy={GPT2Block},
        sharding_strategy="FULL_SHARD",
        cpu_offload=False,
    )
    trainer = L.Trainer(
        accelerator="gpu",
        devices=2,
        strategy=fsdp_strategy,
        precision="bf16-mixed",
        max_epochs=3,
        log_every_n_steps=10,
    )

    dm = WikiDataModule(model_name="gpt2-medium", batch_size=4)
    model = BabyGPT(model_name="gpt2-medium")

    print("Starting FSDP Training... 🌶️")
    trainer.fit(model, datamodule=dm)

if __name__ == "__main__":
    train_fsdp()
# Out:
# Writing train.py

# %%
# !python train.py
# Out:
# 2025-11-22 18:21:45.596552: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763835705.814784      55 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763835705.874001      55 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# tokenizer_config.json: 100%|██████████████████| 26.0/26.0 [00:00<00:00, 202kB/s]
# config.json: 100%|█████████████████████████████| 718/718 [00:00<00:00, 6.07MB/s]
# vocab.json: 100%|██████████████████████████| 1.04M/1.04M [00:00<00:00, 8.26MB/s]
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 6.99MB/s]
# tokenizer.json: 100%|██████████████████████| 1.36M/1.36M [00:00<00:00, 7.24MB/s]
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# model.safetensors: 100%|████████████████████| 1.52G/1.52G [00:04<00:00, 352MB/s]
# generation_config.json: 100%|██████████████████| 124/124 [00:00<00:00, 1.05MB/s]
# Starting FSDP Training... 🌶️
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# 2025-11-22 18:22:25.369346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763835745.391258      96 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763835745.397814      96 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Starting FSDP Training... 🌶️
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# README.md: 10.5kB [00:00, 30.7MB/s]
# wikitext-103-raw-v1/test-00000-of-00001.(…): 100%|█| 733k/733k [00:00<00:00, 2.1
# wikitext-103-raw-v1/train-00000-of-00002(…): 100%|█| 157M/157M [00:01<00:00, 103
# wikitext-103-raw-v1/train-00001-of-00002(…): 100%|█| 157M/157M [00:01<00:00, 141
# wikitext-103-raw-v1/validation-00000-of-(…): 100%|█| 657k/657k [00:00<00:00, 1.3
# Generating test split: 100%|██████| 4358/4358 [00:00<00:00, 84965.80 examples/s]
# Generating train split: 100%|█| 1801350/1801350 [00:02<00:00, 829481.42 examples
# Generating validation split: 100%|█| 3760/3760 [00:00<00:00, 673639.87 examples/
# wikitext-2-raw-v1/train-00000-of-00001.p(…): 100%|█| 6.36M/6.36M [00:00<00:00, 1
# Generating test split: 100%|█████| 4358/4358 [00:00<00:00, 669503.22 examples/s]
# Generating train split: 100%|██| 36718/36718 [00:00<00:00, 874003.76 examples/s]
# Generating validation split: 100%|█| 3760/3760 [00:00<00:00, 593012.82 examples/
# Map: 100%|█████████████████████████| 4358/4358 [00:00<00:00, 6272.22 examples/s]
# Map: 100%|█████████████████████████| 4358/4358 [00:00<00:00, 5906.45 examples/s]
# Map: 100%|███████████████████████| 36718/36718 [00:06<00:00, 6002.17 examples/s]
# Map: 100%|███████████████████████| 36718/36718 [00:06<00:00, 5862.78 examples/s]
# Map: 100%|█████████████████████████| 3760/3760 [00:00<00:00, 7334.10 examples/s]
# Filter: 100%|█████████████████████| 4358/4358 [00:00<00:00, 15482.71 examples/s]
# Map: 100%|█████████████████████████| 3760/3760 [00:00<00:00, 8535.88 examples/s]
# Filter: 100%|█████████████████████| 4358/4358 [00:00<00:00, 25255.55 examples/s]
# Filter: 100%|███████████████████| 36718/36718 [00:01<00:00, 24219.12 examples/s]
# Filter: 100%|█████████████████████| 3760/3760 [00:00<00:00, 23287.93 examples/s]
# Filter: 100%|███████████████████| 36718/36718 [00:01<00:00, 24946.72 examples/s]
# Filter: 100%|█████████████████████| 3760/3760 [00:00<00:00, 24934.79 examples/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/utilities/model_summary/model_summary.py:231: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#   | Name  | Type            | Params | Mode
# -------------------------------------------------
# 0 | model | GPT2LMHeadModel | 177 M  | eval
# -------------------------------------------------
# 177 M     Trainable params
# 0         Non-trainable params
# 177 M     Total params
# 709.646   Total estimated model params size (MB)
# 24        Modules in train mode
# 320       Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]`loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# Sanity Checking DataLoader 0: 100%|███████████████| 2/2 [00:00<00:00,  2.24it/s]/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:434: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:434: It is recommended to use `self.log('val_perplexity', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py:527: Found 320 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Epoch 0: 100%|█| 2971/2971 [35:39<00:00,  1.39it/s, v_num=0, train_loss_step=2.9huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/308 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/308 [00:00<00:58,  5.28it/s]
# Validation DataLoader 0:   1%|                  | 2/308 [00:00<01:07,  4.55it/s]
# Validation DataLoader 0:   1%|▏                 | 3/308 [00:00<01:07,  4.50it/s]
# Validation DataLoader 0:   1%|▏                 | 4/308 [00:00<01:07,  4.49it/s]
# Validation DataLoader 0:   2%|▎                 | 5/308 [00:01<01:07,  4.49it/s]
# Validation DataLoader 0:   2%|▎                 | 6/308 [00:01<01:07,  4.46it/s]
# Validation DataLoader 0:   2%|▍                 | 7/308 [00:01<01:07,  4.44it/s]
# Validation DataLoader 0:   3%|▍                 | 8/308 [00:01<01:07,  4.42it/s]
# Validation DataLoader 0:   3%|▌                 | 9/308 [00:02<01:07,  4.40it/s]
# Validation DataLoader 0:   3%|▌                | 10/308 [00:02<01:07,  4.39it/s]
# Validation DataLoader 0:   4%|▌                | 11/308 [00:02<01:07,  4.38it/s]
# Validation DataLoader 0:   4%|▋                | 12/308 [00:02<01:07,  4.38it/s]
# Validation DataLoader 0:   4%|▋                | 13/308 [00:02<01:07,  4.38it/s]
# Validation DataLoader 0:   5%|▊                | 14/308 [00:03<01:06,  4.43it/s]
# Validation DataLoader 0:   5%|▊                | 15/308 [00:03<01:06,  4.44it/s]
# Validation DataLoader 0:   5%|▉                | 16/308 [00:03<01:05,  4.43it/s]
# Validation DataLoader 0:   6%|▉                | 17/308 [00:03<01:05,  4.42it/s]
# Validation DataLoader 0:   6%|▉                | 18/308 [00:04<01:05,  4.41it/s]
# Validation DataLoader 0:   6%|█                | 19/308 [00:04<01:05,  4.41it/s]
# Validation DataLoader 0:   6%|█                | 20/308 [00:04<01:05,  4.40it/s]
# Validation DataLoader 0:   7%|█▏               | 21/308 [00:04<01:05,  4.39it/s]
# Validation DataLoader 0:   7%|█▏               | 22/308 [00:04<01:04,  4.46it/s]
# Validation DataLoader 0:   7%|█▎               | 23/308 [00:05<01:02,  4.55it/s]
# Validation DataLoader 0:   8%|█▎               | 24/308 [00:05<01:02,  4.57it/s]
# Validation DataLoader 0:   8%|█▍               | 25/308 [00:05<01:01,  4.57it/s]
# Validation DataLoader 0:   8%|█▍               | 26/308 [00:05<01:00,  4.63it/s]
# Validation DataLoader 0:   9%|█▍               | 27/308 [00:05<01:00,  4.66it/s]
# Validation DataLoader 0:   9%|█▌               | 28/308 [00:05<00:59,  4.68it/s]
# Validation DataLoader 0:   9%|█▌               | 29/308 [00:06<00:59,  4.72it/s]
# Validation DataLoader 0:  10%|█▋               | 30/308 [00:06<00:58,  4.71it/s]
# Validation DataLoader 0:  10%|█▋               | 31/308 [00:06<00:58,  4.70it/s]
# Validation DataLoader 0:  10%|█▊               | 32/308 [00:06<00:58,  4.68it/s]
# Validation DataLoader 0:  11%|█▊               | 33/308 [00:07<00:58,  4.68it/s]
# Validation DataLoader 0:  11%|█▉               | 34/308 [00:07<00:58,  4.67it/s]
# Validation DataLoader 0:  11%|█▉               | 35/308 [00:07<00:58,  4.67it/s]
# Validation DataLoader 0:  12%|█▉               | 36/308 [00:07<00:57,  4.69it/s]
# Validation DataLoader 0:  12%|██               | 37/308 [00:07<00:57,  4.70it/s]
# Validation DataLoader 0:  12%|██               | 38/308 [00:08<00:57,  4.69it/s]
# Validation DataLoader 0:  13%|██▏              | 39/308 [00:08<00:57,  4.69it/s]
# Validation DataLoader 0:  13%|██▏              | 40/308 [00:08<00:57,  4.68it/s]
# Validation DataLoader 0:  13%|██▎              | 41/308 [00:08<00:57,  4.67it/s]
# Validation DataLoader 0:  14%|██▎              | 42/308 [00:08<00:56,  4.67it/s]
# Validation DataLoader 0:  14%|██▎              | 43/308 [00:09<00:56,  4.67it/s]
# Validation DataLoader 0:  14%|██▍              | 44/308 [00:09<00:56,  4.67it/s]
# Validation DataLoader 0:  15%|██▍              | 45/308 [00:09<00:56,  4.66it/s]
# Validation DataLoader 0:  15%|██▌              | 46/308 [00:09<00:56,  4.66it/s]
# Validation DataLoader 0:  15%|██▌              | 47/308 [00:10<00:56,  4.65it/s]
# Validation DataLoader 0:  16%|██▋              | 48/308 [00:10<00:55,  4.64it/s]
# Validation DataLoader 0:  16%|██▋              | 49/308 [00:10<00:55,  4.64it/s]
# Validation DataLoader 0:  16%|██▊              | 50/308 [00:10<00:55,  4.63it/s]
# Validation DataLoader 0:  17%|██▊              | 51/308 [00:11<00:55,  4.62it/s]
# Validation DataLoader 0:  17%|██▊              | 52/308 [00:11<00:55,  4.62it/s]
# Validation DataLoader 0:  17%|██▉              | 53/308 [00:11<00:54,  4.65it/s]
# Validation DataLoader 0:  18%|██▉              | 54/308 [00:11<00:54,  4.69it/s]
# Validation DataLoader 0:  18%|███              | 55/308 [00:11<00:53,  4.70it/s]
# Validation DataLoader 0:  18%|███              | 56/308 [00:11<00:53,  4.70it/s]
# Validation DataLoader 0:  19%|███▏             | 57/308 [00:12<00:53,  4.70it/s]
# Validation DataLoader 0:  19%|███▏             | 58/308 [00:12<00:53,  4.69it/s]
# Validation DataLoader 0:  19%|███▎             | 59/308 [00:12<00:53,  4.68it/s]
# Validation DataLoader 0:  19%|███▎             | 60/308 [00:12<00:53,  4.68it/s]
# Validation DataLoader 0:  20%|███▎             | 61/308 [00:13<00:52,  4.67it/s]
# Validation DataLoader 0:  20%|███▍             | 62/308 [00:13<00:52,  4.70it/s]
# Validation DataLoader 0:  20%|███▍             | 63/308 [00:13<00:52,  4.70it/s]
# Validation DataLoader 0:  21%|███▌             | 64/308 [00:13<00:51,  4.70it/s]
# Validation DataLoader 0:  21%|███▌             | 65/308 [00:13<00:51,  4.69it/s]
# Validation DataLoader 0:  21%|███▋             | 66/308 [00:14<00:51,  4.68it/s]
# Validation DataLoader 0:  22%|███▋             | 67/308 [00:14<00:51,  4.68it/s]
# Validation DataLoader 0:  22%|███▊             | 68/308 [00:14<00:51,  4.67it/s]
# Validation DataLoader 0:  22%|███▊             | 69/308 [00:14<00:51,  4.67it/s]
# Validation DataLoader 0:  23%|███▊             | 70/308 [00:15<00:51,  4.67it/s]
# Validation DataLoader 0:  23%|███▉             | 71/308 [00:15<00:50,  4.66it/s]
# Validation DataLoader 0:  23%|███▉             | 72/308 [00:15<00:50,  4.66it/s]
# Validation DataLoader 0:  24%|████             | 73/308 [00:15<00:50,  4.66it/s]
# Validation DataLoader 0:  24%|████             | 74/308 [00:15<00:50,  4.65it/s]
# Validation DataLoader 0:  24%|████▏            | 75/308 [00:16<00:49,  4.67it/s]
# Validation DataLoader 0:  25%|████▏            | 76/308 [00:16<00:49,  4.71it/s]
# Validation DataLoader 0:  25%|████▎            | 77/308 [00:16<00:49,  4.71it/s]
# Validation DataLoader 0:  25%|████▎            | 78/308 [00:16<00:48,  4.70it/s]
# Validation DataLoader 0:  26%|████▎            | 79/308 [00:16<00:48,  4.70it/s]
# Validation DataLoader 0:  26%|████▍            | 80/308 [00:17<00:48,  4.69it/s]
# Validation DataLoader 0:  26%|████▍            | 81/308 [00:17<00:48,  4.69it/s]
# Validation DataLoader 0:  27%|████▌            | 82/308 [00:17<00:48,  4.68it/s]
# Validation DataLoader 0:  27%|████▌            | 83/308 [00:17<00:48,  4.68it/s]
# Validation DataLoader 0:  27%|████▋            | 84/308 [00:17<00:47,  4.68it/s]
# Validation DataLoader 0:  28%|████▋            | 85/308 [00:18<00:47,  4.67it/s]
# Validation DataLoader 0:  28%|████▋            | 86/308 [00:18<00:47,  4.67it/s]
# Validation DataLoader 0:  28%|████▊            | 87/308 [00:18<00:47,  4.66it/s]
# Validation DataLoader 0:  29%|████▊            | 88/308 [00:18<00:47,  4.66it/s]
# Validation DataLoader 0:  29%|████▉            | 89/308 [00:19<00:47,  4.65it/s]
# Validation DataLoader 0:  29%|████▉            | 90/308 [00:19<00:46,  4.65it/s]
# Validation DataLoader 0:  30%|█████            | 91/308 [00:19<00:46,  4.65it/s]
# Validation DataLoader 0:  30%|█████            | 92/308 [00:19<00:46,  4.65it/s]
# Validation DataLoader 0:  30%|█████▏           | 93/308 [00:20<00:46,  4.64it/s]
# Validation DataLoader 0:  31%|█████▏           | 94/308 [00:20<00:46,  4.64it/s]
# Validation DataLoader 0:  31%|█████▏           | 95/308 [00:20<00:45,  4.64it/s]
# Validation DataLoader 0:  31%|█████▎           | 96/308 [00:20<00:45,  4.63it/s]
# Validation DataLoader 0:  31%|█████▎           | 97/308 [00:20<00:45,  4.63it/s]
# Validation DataLoader 0:  32%|█████▍           | 98/308 [00:21<00:45,  4.62it/s]
# Validation DataLoader 0:  32%|█████▍           | 99/308 [00:21<00:45,  4.62it/s]
# Validation DataLoader 0:  32%|█████▏          | 100/308 [00:21<00:45,  4.62it/s]
# Validation DataLoader 0:  33%|█████▏          | 101/308 [00:21<00:44,  4.61it/s]
# Validation DataLoader 0:  33%|█████▎          | 102/308 [00:22<00:44,  4.61it/s]
# Validation DataLoader 0:  33%|█████▎          | 103/308 [00:22<00:44,  4.61it/s]
# Validation DataLoader 0:  34%|█████▍          | 104/308 [00:22<00:44,  4.60it/s]
# Validation DataLoader 0:  34%|█████▍          | 105/308 [00:22<00:44,  4.60it/s]
# Validation DataLoader 0:  34%|█████▌          | 106/308 [00:23<00:43,  4.60it/s]
# Validation DataLoader 0:  35%|█████▌          | 107/308 [00:23<00:43,  4.59it/s]
# Validation DataLoader 0:  35%|█████▌          | 108/308 [00:23<00:43,  4.59it/s]
# Validation DataLoader 0:  35%|█████▋          | 109/308 [00:23<00:43,  4.59it/s]
# Validation DataLoader 0:  36%|█████▋          | 110/308 [00:23<00:43,  4.58it/s]
# Validation DataLoader 0:  36%|█████▊          | 111/308 [00:24<00:43,  4.58it/s]
# Validation DataLoader 0:  36%|█████▊          | 112/308 [00:24<00:42,  4.58it/s]
# Validation DataLoader 0:  37%|█████▊          | 113/308 [00:24<00:42,  4.57it/s]
# Validation DataLoader 0:  37%|█████▉          | 114/308 [00:24<00:42,  4.57it/s]
# Validation DataLoader 0:  37%|█████▉          | 115/308 [00:25<00:42,  4.57it/s]
# Validation DataLoader 0:  38%|██████          | 116/308 [00:25<00:41,  4.57it/s]
# Validation DataLoader 0:  38%|██████          | 117/308 [00:25<00:41,  4.57it/s]
# Validation DataLoader 0:  38%|██████▏         | 118/308 [00:25<00:41,  4.57it/s]
# Validation DataLoader 0:  39%|██████▏         | 119/308 [00:26<00:41,  4.57it/s]
# Validation DataLoader 0:  39%|██████▏         | 120/308 [00:26<00:41,  4.56it/s]
# Validation DataLoader 0:  39%|██████▎         | 121/308 [00:26<00:40,  4.56it/s]
# Validation DataLoader 0:  40%|██████▎         | 122/308 [00:26<00:40,  4.56it/s]
# Validation DataLoader 0:  40%|██████▍         | 123/308 [00:26<00:40,  4.56it/s]
# Validation DataLoader 0:  40%|██████▍         | 124/308 [00:27<00:40,  4.55it/s]
# Validation DataLoader 0:  41%|██████▍         | 125/308 [00:27<00:40,  4.55it/s]
# Validation DataLoader 0:  41%|██████▌         | 126/308 [00:27<00:39,  4.56it/s]
# Validation DataLoader 0:  41%|██████▌         | 127/308 [00:27<00:39,  4.57it/s]
# Validation DataLoader 0:  42%|██████▋         | 128/308 [00:28<00:39,  4.57it/s]
# Validation DataLoader 0:  42%|██████▋         | 129/308 [00:28<00:39,  4.57it/s]
# Validation DataLoader 0:  42%|██████▊         | 130/308 [00:28<00:38,  4.57it/s]
# Validation DataLoader 0:  43%|██████▊         | 131/308 [00:28<00:38,  4.57it/s]
# Validation DataLoader 0:  43%|██████▊         | 132/308 [00:28<00:38,  4.57it/s]
# Validation DataLoader 0:  43%|██████▉         | 133/308 [00:29<00:38,  4.56it/s]
# Validation DataLoader 0:  44%|██████▉         | 134/308 [00:29<00:38,  4.56it/s]
# Validation DataLoader 0:  44%|███████         | 135/308 [00:29<00:37,  4.56it/s]
# Validation DataLoader 0:  44%|███████         | 136/308 [00:29<00:37,  4.56it/s]
# Validation DataLoader 0:  44%|███████         | 137/308 [00:30<00:37,  4.55it/s]
# Validation DataLoader 0:  45%|███████▏        | 138/308 [00:30<00:37,  4.55it/s]
# Validation DataLoader 0:  45%|███████▏        | 139/308 [00:30<00:37,  4.55it/s]
# Validation DataLoader 0:  45%|███████▎        | 140/308 [00:30<00:36,  4.55it/s]
# Validation DataLoader 0:  46%|███████▎        | 141/308 [00:31<00:36,  4.55it/s]
# Validation DataLoader 0:  46%|███████▍        | 142/308 [00:31<00:36,  4.54it/s]
# Validation DataLoader 0:  46%|███████▍        | 143/308 [00:31<00:36,  4.54it/s]
# Validation DataLoader 0:  47%|███████▍        | 144/308 [00:31<00:36,  4.54it/s]
# Validation DataLoader 0:  47%|███████▌        | 145/308 [00:31<00:35,  4.54it/s]
# Validation DataLoader 0:  47%|███████▌        | 146/308 [00:32<00:35,  4.54it/s]
# Validation DataLoader 0:  48%|███████▋        | 147/308 [00:32<00:35,  4.53it/s]
# Validation DataLoader 0:  48%|███████▋        | 148/308 [00:32<00:35,  4.53it/s]
# Validation DataLoader 0:  48%|███████▋        | 149/308 [00:32<00:35,  4.53it/s]
# Validation DataLoader 0:  49%|███████▊        | 150/308 [00:33<00:34,  4.53it/s]
# Validation DataLoader 0:  49%|███████▊        | 151/308 [00:33<00:34,  4.53it/s]
# Validation DataLoader 0:  49%|███████▉        | 152/308 [00:33<00:34,  4.52it/s]
# Validation DataLoader 0:  50%|███████▉        | 153/308 [00:33<00:34,  4.52it/s]
# Validation DataLoader 0:  50%|████████        | 154/308 [00:34<00:34,  4.52it/s]
# Validation DataLoader 0:  50%|████████        | 155/308 [00:34<00:33,  4.52it/s]
# Validation DataLoader 0:  51%|████████        | 156/308 [00:34<00:33,  4.52it/s]
# Validation DataLoader 0:  51%|████████▏       | 157/308 [00:34<00:33,  4.52it/s]
# Validation DataLoader 0:  51%|████████▏       | 158/308 [00:35<00:33,  4.51it/s]
# Validation DataLoader 0:  52%|████████▎       | 159/308 [00:35<00:33,  4.51it/s]
# Validation DataLoader 0:  52%|████████▎       | 160/308 [00:35<00:32,  4.51it/s]
# Validation DataLoader 0:  52%|████████▎       | 161/308 [00:35<00:32,  4.51it/s]
# Validation DataLoader 0:  53%|████████▍       | 162/308 [00:35<00:32,  4.51it/s]
# Validation DataLoader 0:  53%|████████▍       | 163/308 [00:36<00:32,  4.51it/s]
# Validation DataLoader 0:  53%|████████▌       | 164/308 [00:36<00:31,  4.51it/s]
# Validation DataLoader 0:  54%|████████▌       | 165/308 [00:36<00:31,  4.51it/s]
# Validation DataLoader 0:  54%|████████▌       | 166/308 [00:36<00:31,  4.51it/s]
# Validation DataLoader 0:  54%|████████▋       | 167/308 [00:37<00:31,  4.51it/s]
# Validation DataLoader 0:  55%|████████▋       | 168/308 [00:37<00:31,  4.51it/s]
# Validation DataLoader 0:  55%|████████▊       | 169/308 [00:37<00:30,  4.50it/s]
# Validation DataLoader 0:  55%|████████▊       | 170/308 [00:37<00:30,  4.50it/s]
# Validation DataLoader 0:  56%|████████▉       | 171/308 [00:37<00:30,  4.50it/s]
# Validation DataLoader 0:  56%|████████▉       | 172/308 [00:38<00:30,  4.50it/s]
# Validation DataLoader 0:  56%|████████▉       | 173/308 [00:38<00:30,  4.50it/s]
# Validation DataLoader 0:  56%|█████████       | 174/308 [00:38<00:29,  4.50it/s]
# Validation DataLoader 0:  57%|█████████       | 175/308 [00:38<00:29,  4.50it/s]
# Validation DataLoader 0:  57%|█████████▏      | 176/308 [00:39<00:29,  4.49it/s]
# Validation DataLoader 0:  57%|█████████▏      | 177/308 [00:39<00:29,  4.49it/s]
# Validation DataLoader 0:  58%|█████████▏      | 178/308 [00:39<00:28,  4.50it/s]
# Validation DataLoader 0:  58%|█████████▎      | 179/308 [00:39<00:28,  4.50it/s]
# Validation DataLoader 0:  58%|█████████▎      | 180/308 [00:40<00:28,  4.49it/s]
# Validation DataLoader 0:  59%|█████████▍      | 181/308 [00:40<00:28,  4.49it/s]
# Validation DataLoader 0:  59%|█████████▍      | 182/308 [00:40<00:28,  4.49it/s]
# Validation DataLoader 0:  59%|█████████▌      | 183/308 [00:40<00:27,  4.49it/s]
# Validation DataLoader 0:  60%|█████████▌      | 184/308 [00:40<00:27,  4.49it/s]
# Validation DataLoader 0:  60%|█████████▌      | 185/308 [00:41<00:27,  4.49it/s]
# Validation DataLoader 0:  60%|█████████▋      | 186/308 [00:41<00:27,  4.49it/s]
# Validation DataLoader 0:  61%|█████████▋      | 187/308 [00:41<00:26,  4.48it/s]
# Validation DataLoader 0:  61%|█████████▊      | 188/308 [00:41<00:26,  4.48it/s]
# Validation DataLoader 0:  61%|█████████▊      | 189/308 [00:42<00:26,  4.48it/s]
# Validation DataLoader 0:  62%|█████████▊      | 190/308 [00:42<00:26,  4.48it/s]
# Validation DataLoader 0:  62%|█████████▉      | 191/308 [00:42<00:26,  4.48it/s]
# Validation DataLoader 0:  62%|█████████▉      | 192/308 [00:42<00:25,  4.48it/s]
# Validation DataLoader 0:  63%|██████████      | 193/308 [00:43<00:25,  4.48it/s]
# Validation DataLoader 0:  63%|██████████      | 194/308 [00:43<00:25,  4.48it/s]
# Validation DataLoader 0:  63%|██████████▏     | 195/308 [00:43<00:25,  4.48it/s]
# Validation DataLoader 0:  64%|██████████▏     | 196/308 [00:43<00:25,  4.48it/s]
# Validation DataLoader 0:  64%|██████████▏     | 197/308 [00:44<00:24,  4.47it/s]
# Validation DataLoader 0:  64%|██████████▎     | 198/308 [00:44<00:24,  4.48it/s]
# Validation DataLoader 0:  65%|██████████▎     | 199/308 [00:44<00:24,  4.48it/s]
# Validation DataLoader 0:  65%|██████████▍     | 200/308 [00:44<00:24,  4.47it/s]
# Validation DataLoader 0:  65%|██████████▍     | 201/308 [00:44<00:23,  4.47it/s]
# Validation DataLoader 0:  66%|██████████▍     | 202/308 [00:45<00:23,  4.47it/s]
# Validation DataLoader 0:  66%|██████████▌     | 203/308 [00:45<00:23,  4.47it/s]
# Validation DataLoader 0:  66%|██████████▌     | 204/308 [00:45<00:23,  4.47it/s]
# Validation DataLoader 0:  67%|██████████▋     | 205/308 [00:45<00:23,  4.47it/s]
# Validation DataLoader 0:  67%|██████████▋     | 206/308 [00:46<00:22,  4.47it/s]
# Validation DataLoader 0:  67%|██████████▊     | 207/308 [00:46<00:22,  4.48it/s]
# Validation DataLoader 0:  68%|██████████▊     | 208/308 [00:46<00:22,  4.49it/s]
# Validation DataLoader 0:  68%|██████████▊     | 209/308 [00:46<00:22,  4.50it/s]
# Validation DataLoader 0:  68%|██████████▉     | 210/308 [00:46<00:21,  4.51it/s]
# Validation DataLoader 0:  69%|██████████▉     | 211/308 [00:46<00:21,  4.52it/s]
# Validation DataLoader 0:  69%|███████████     | 212/308 [00:46<00:21,  4.52it/s]
# Validation DataLoader 0:  69%|███████████     | 213/308 [00:47<00:21,  4.52it/s]
# Validation DataLoader 0:  69%|███████████     | 214/308 [00:47<00:20,  4.51it/s]
# Validation DataLoader 0:  70%|███████████▏    | 215/308 [00:47<00:20,  4.51it/s]
# Validation DataLoader 0:  70%|███████████▏    | 216/308 [00:47<00:20,  4.51it/s]
# Validation DataLoader 0:  70%|███████████▎    | 217/308 [00:48<00:20,  4.52it/s]
# Validation DataLoader 0:  71%|███████████▎    | 218/308 [00:48<00:19,  4.52it/s]
# Validation DataLoader 0:  71%|███████████▍    | 219/308 [00:48<00:19,  4.53it/s]
# Validation DataLoader 0:  71%|███████████▍    | 220/308 [00:48<00:19,  4.53it/s]
# Validation DataLoader 0:  72%|███████████▍    | 221/308 [00:48<00:19,  4.53it/s]
# Validation DataLoader 0:  72%|███████████▌    | 222/308 [00:49<00:19,  4.53it/s]
# Validation DataLoader 0:  72%|███████████▌    | 223/308 [00:49<00:18,  4.52it/s]
# Validation DataLoader 0:  73%|███████████▋    | 224/308 [00:49<00:18,  4.52it/s]
# Validation DataLoader 0:  73%|███████████▋    | 225/308 [00:49<00:18,  4.52it/s]
# Validation DataLoader 0:  73%|███████████▋    | 226/308 [00:49<00:18,  4.52it/s]
# Validation DataLoader 0:  74%|███████████▊    | 227/308 [00:50<00:17,  4.52it/s]
# Validation DataLoader 0:  74%|███████████▊    | 228/308 [00:50<00:17,  4.52it/s]
# Validation DataLoader 0:  74%|███████████▉    | 229/308 [00:50<00:17,  4.52it/s]
# Validation DataLoader 0:  75%|███████████▉    | 230/308 [00:50<00:17,  4.52it/s]
# Validation DataLoader 0:  75%|████████████    | 231/308 [00:51<00:17,  4.52it/s]
# Validation DataLoader 0:  75%|████████████    | 232/308 [00:51<00:16,  4.51it/s]
# Validation DataLoader 0:  76%|████████████    | 233/308 [00:51<00:16,  4.51it/s]
# Validation DataLoader 0:  76%|████████████▏   | 234/308 [00:51<00:16,  4.51it/s]
# Validation DataLoader 0:  76%|████████████▏   | 235/308 [00:52<00:16,  4.51it/s]
# Validation DataLoader 0:  77%|████████████▎   | 236/308 [00:52<00:15,  4.51it/s]
# Validation DataLoader 0:  77%|████████████▎   | 237/308 [00:52<00:15,  4.51it/s]
# Validation DataLoader 0:  77%|████████████▎   | 238/308 [00:52<00:15,  4.51it/s]
# Validation DataLoader 0:  78%|████████████▍   | 239/308 [00:53<00:15,  4.51it/s]
# Validation DataLoader 0:  78%|████████████▍   | 240/308 [00:53<00:15,  4.51it/s]
# Validation DataLoader 0:  78%|████████████▌   | 241/308 [00:53<00:14,  4.51it/s]
# Validation DataLoader 0:  79%|████████████▌   | 242/308 [00:53<00:14,  4.51it/s]
# Validation DataLoader 0:  79%|████████████▌   | 243/308 [00:53<00:14,  4.50it/s]
# Validation DataLoader 0:  79%|████████████▋   | 244/308 [00:54<00:14,  4.50it/s]
# Validation DataLoader 0:  80%|████████████▋   | 245/308 [00:54<00:13,  4.50it/s]
# Validation DataLoader 0:  80%|████████████▊   | 246/308 [00:54<00:13,  4.50it/s]
# Validation DataLoader 0:  80%|████████████▊   | 247/308 [00:54<00:13,  4.50it/s]
# Validation DataLoader 0:  81%|████████████▉   | 248/308 [00:55<00:13,  4.50it/s]
# Validation DataLoader 0:  81%|████████████▉   | 249/308 [00:55<00:13,  4.50it/s]
# Validation DataLoader 0:  81%|████████████▉   | 250/308 [00:55<00:12,  4.50it/s]
# Validation DataLoader 0:  81%|█████████████   | 251/308 [00:55<00:12,  4.50it/s]
# Validation DataLoader 0:  82%|█████████████   | 252/308 [00:56<00:12,  4.50it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 253/308 [00:56<00:12,  4.50it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 254/308 [00:56<00:11,  4.51it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 255/308 [00:56<00:11,  4.51it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 256/308 [00:56<00:11,  4.52it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 257/308 [00:56<00:11,  4.52it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 258/308 [00:57<00:11,  4.52it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 259/308 [00:57<00:10,  4.52it/s]
# Validation DataLoader 0:  84%|█████████████▌  | 260/308 [00:57<00:10,  4.52it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 261/308 [00:57<00:10,  4.51it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 262/308 [00:58<00:10,  4.51it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 263/308 [00:58<00:09,  4.51it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 264/308 [00:58<00:09,  4.51it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 265/308 [00:58<00:09,  4.51it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 266/308 [00:58<00:09,  4.51it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 267/308 [00:59<00:09,  4.51it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 268/308 [00:59<00:08,  4.51it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 269/308 [00:59<00:08,  4.51it/s]
# Validation DataLoader 0:  88%|██████████████  | 270/308 [00:59<00:08,  4.51it/s]
# Validation DataLoader 0:  88%|██████████████  | 271/308 [01:00<00:08,  4.51it/s]
# Validation DataLoader 0:  88%|██████████████▏ | 272/308 [01:00<00:07,  4.51it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 273/308 [01:00<00:07,  4.50it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 274/308 [01:00<00:07,  4.51it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 275/308 [01:00<00:07,  4.51it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 276/308 [01:01<00:07,  4.51it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 277/308 [01:01<00:06,  4.51it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 278/308 [01:01<00:06,  4.51it/s]
# Validation DataLoader 0:  91%|██████████████▍ | 279/308 [01:01<00:06,  4.51it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 280/308 [01:02<00:06,  4.51it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 281/308 [01:02<00:05,  4.51it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 282/308 [01:02<00:05,  4.51it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 283/308 [01:02<00:05,  4.51it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 284/308 [01:02<00:05,  4.51it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 285/308 [01:03<00:05,  4.51it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 286/308 [01:03<00:04,  4.51it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 287/308 [01:03<00:04,  4.51it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 288/308 [01:03<00:04,  4.51it/s]
# Validation DataLoader 0:  94%|███████████████ | 289/308 [01:04<00:04,  4.51it/s]
# Validation DataLoader 0:  94%|███████████████ | 290/308 [01:04<00:03,  4.51it/s]
# Validation DataLoader 0:  94%|███████████████ | 291/308 [01:04<00:03,  4.50it/s]
# Validation DataLoader 0:  95%|███████████████▏| 292/308 [01:04<00:03,  4.50it/s]
# Validation DataLoader 0:  95%|███████████████▏| 293/308 [01:05<00:03,  4.50it/s]
# Validation DataLoader 0:  95%|███████████████▎| 294/308 [01:05<00:03,  4.50it/s]
# Validation DataLoader 0:  96%|███████████████▎| 295/308 [01:05<00:02,  4.50it/s]
# Validation DataLoader 0:  96%|███████████████▍| 296/308 [01:05<00:02,  4.50it/s]
# Validation DataLoader 0:  96%|███████████████▍| 297/308 [01:06<00:02,  4.50it/s]
# Validation DataLoader 0:  97%|███████████████▍| 298/308 [01:06<00:02,  4.50it/s]
# Validation DataLoader 0:  97%|███████████████▌| 299/308 [01:06<00:02,  4.50it/s]
# Validation DataLoader 0:  97%|███████████████▌| 300/308 [01:06<00:01,  4.50it/s]
# Validation DataLoader 0:  98%|███████████████▋| 301/308 [01:06<00:01,  4.51it/s]
# Validation DataLoader 0:  98%|███████████████▋| 302/308 [01:06<00:01,  4.51it/s]
# Validation DataLoader 0:  98%|███████████████▋| 303/308 [01:07<00:01,  4.51it/s]
# Validation DataLoader 0:  99%|███████████████▊| 304/308 [01:07<00:00,  4.51it/s]
# Validation DataLoader 0:  99%|███████████████▊| 305/308 [01:07<00:00,  4.51it/s]
# Validation DataLoader 0:  99%|███████████████▉| 306/308 [01:07<00:00,  4.51it/s]
# Validation DataLoader 0: 100%|███████████████▉| 307/308 [01:08<00:00,  4.51it/s]
# Validation DataLoader 0: 100%|████████████████| 308/308 [01:08<00:00,  4.51it/s]
# Epoch 0: 100%|█| 2971/2971 [36:47<00:00,  1.35it/s, v_num=0, train_loss_step=2.9/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:434: It is recommended to use `self.log('train_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Epoch 1:   0%| | 0/2971 [00:00<?, ?it/s, v_num=0, train_loss_step=2.960, val_loshuggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...
# Validation DataLoader 0:  37%|█████▉          | 115/308 [00:25<00:43,  4.45it/s]
# Validation DataLoader 0:  38%|██████          | 116/308 [00:26<00:43,  4.45it/s]
# Validation DataLoader 0:  38%|██████          | 117/308 [00:26<00:42,  4.45it/s]
# Validation DataLoader 0:  38%|██████▏         | 118/308 [00:26<00:42,  4.45it/s]
# Validation DataLoader 0:  39%|██████▏         | 119/308 [00:26<00:42,  4.45it/s]
# Validation DataLoader 0:  39%|██████▏         | 120/308 [00:26<00:42,  4.45it/s]
# Validation DataLoader 0:  39%|██████▎         | 121/308 [00:27<00:42,  4.45it/s]
# Validation DataLoader 0:  40%|██████▎         | 122/308 [00:27<00:41,  4.45it/s]
# Validation DataLoader 0:  40%|██████▍         | 123/308 [00:27<00:41,  4.44it/s]
# Validation DataLoader 0:  40%|██████▍         | 124/308 [00:27<00:41,  4.44it/s]
# Validation DataLoader 0:  41%|██████▍         | 125/308 [00:28<00:41,  4.44it/s]
# Validation DataLoader 0:  41%|██████▌         | 126/308 [00:28<00:40,  4.45it/s]
# Validation DataLoader 0:  41%|██████▌         | 127/308 [00:28<00:40,  4.46it/s]
# Validation DataLoader 0:  42%|██████▋         | 128/308 [00:28<00:40,  4.46it/s]
# Validation DataLoader 0:  42%|██████▋         | 129/308 [00:28<00:40,  4.46it/s]
# Validation DataLoader 0:  42%|██████▊         | 130/308 [00:29<00:39,  4.47it/s]
# Validation DataLoader 0:  43%|██████▊         | 131/308 [00:29<00:39,  4.46it/s]
# Validation DataLoader 0:  43%|██████▊         | 132/308 [00:29<00:39,  4.46it/s]
# Validation DataLoader 0:  43%|██████▉         | 133/308 [00:29<00:39,  4.46it/s]
# Validation DataLoader 0:  44%|██████▉         | 134/308 [00:30<00:39,  4.46it/s]
# Validation DataLoader 0:  44%|███████         | 135/308 [00:30<00:38,  4.46it/s]
# Validation DataLoader 0:  44%|███████         | 136/308 [00:30<00:38,  4.46it/s]
# Validation DataLoader 0:  44%|███████         | 137/308 [00:30<00:38,  4.46it/s]
# Validation DataLoader 0:  45%|███████▏        | 138/308 [00:30<00:38,  4.46it/s]
# Validation DataLoader 0:  45%|███████▏        | 139/308 [00:31<00:37,  4.45it/s]
# Validation DataLoader 0:  45%|███████▎        | 140/308 [00:31<00:37,  4.45it/s]
# Validation DataLoader 0:  46%|███████▎        | 141/308 [00:31<00:37,  4.45it/s]
# Validation DataLoader 0:  46%|███████▍        | 142/308 [00:31<00:37,  4.45it/s]
# Validation DataLoader 0:  46%|███████▍        | 143/308 [00:32<00:37,  4.45it/s]
# Validation DataLoader 0:  47%|███████▍        | 144/308 [00:32<00:36,  4.45it/s]
# Validation DataLoader 0:  47%|███████▌        | 145/308 [00:32<00:36,  4.45it/s]
# Validation DataLoader 0:  47%|███████▌        | 146/308 [00:32<00:36,  4.45it/s]
# Validation DataLoader 0:  48%|███████▋        | 147/308 [00:33<00:36,  4.44it/s]
# Validation DataLoader 0:  48%|███████▋        | 148/308 [00:33<00:36,  4.44it/s]
# Validation DataLoader 0:  48%|███████▋        | 149/308 [00:33<00:35,  4.44it/s]
# Validation DataLoader 0:  49%|███████▊        | 150/308 [00:33<00:35,  4.44it/s]
# Validation DataLoader 0:  49%|███████▊        | 151/308 [00:34<00:35,  4.44it/s]
# Validation DataLoader 0:  49%|███████▉        | 152/308 [00:34<00:35,  4.44it/s]
# Validation DataLoader 0:  50%|███████▉        | 153/308 [00:34<00:34,  4.44it/s]
# Validation DataLoader 0:  50%|████████        | 154/308 [00:34<00:34,  4.44it/s]
# Validation DataLoader 0:  50%|████████        | 155/308 [00:34<00:34,  4.44it/s]
# Validation DataLoader 0:  51%|████████        | 156/308 [00:35<00:34,  4.44it/s]
# Validation DataLoader 0:  51%|████████▏       | 157/308 [00:35<00:34,  4.43it/s]
# Validation DataLoader 0:  51%|████████▏       | 158/308 [00:35<00:33,  4.43it/s]
# Validation DataLoader 0:  52%|████████▎       | 159/308 [00:35<00:33,  4.43it/s]
# Validation DataLoader 0:  52%|████████▎       | 160/308 [00:36<00:33,  4.43it/s]
# Validation DataLoader 0:  52%|████████▎       | 161/308 [00:36<00:33,  4.44it/s]
# Validation DataLoader 0:  53%|████████▍       | 162/308 [00:36<00:32,  4.44it/s]
# Validation DataLoader 0:  53%|████████▍       | 163/308 [00:36<00:32,  4.44it/s]
# Validation DataLoader 0:  53%|████████▌       | 164/308 [00:36<00:32,  4.43it/s]
# Validation DataLoader 0:  54%|████████▌       | 165/308 [00:37<00:32,  4.43it/s]
# Validation DataLoader 0:  54%|████████▌       | 166/308 [00:37<00:32,  4.43it/s]
# Validation DataLoader 0:  54%|████████▋       | 167/308 [00:37<00:31,  4.43it/s]
# Validation DataLoader 0:  55%|████████▋       | 168/308 [00:37<00:31,  4.43it/s]
# Validation DataLoader 0:  55%|████████▊       | 169/308 [00:38<00:31,  4.43it/s]
# Validation DataLoader 0:  55%|████████▊       | 170/308 [00:38<00:31,  4.43it/s]
# Validation DataLoader 0:  56%|████████▉       | 171/308 [00:38<00:30,  4.43it/s]
# Validation DataLoader 0:  56%|████████▉       | 172/308 [00:38<00:30,  4.43it/s]
# Validation DataLoader 0:  56%|████████▉       | 173/308 [00:39<00:30,  4.43it/s]
# Validation DataLoader 0:  56%|█████████       | 174/308 [00:39<00:30,  4.43it/s]
# Validation DataLoader 0:  57%|█████████       | 175/308 [00:39<00:30,  4.43it/s]
# Validation DataLoader 0:  57%|█████████▏      | 176/308 [00:39<00:29,  4.43it/s]
# Validation DataLoader 0:  57%|█████████▏      | 177/308 [00:39<00:29,  4.43it/s]
# Validation DataLoader 0:  58%|█████████▏      | 178/308 [00:40<00:29,  4.43it/s]
# Validation DataLoader 0:  58%|█████████▎      | 179/308 [00:40<00:29,  4.43it/s]
# Validation DataLoader 0:  58%|█████████▎      | 180/308 [00:40<00:28,  4.43it/s]
# Validation DataLoader 0:  59%|█████████▍      | 181/308 [00:40<00:28,  4.43it/s]
# Validation DataLoader 0:  59%|█████████▍      | 182/308 [00:41<00:28,  4.43it/s]
# Validation DataLoader 0:  59%|█████████▌      | 183/308 [00:41<00:28,  4.43it/s]
# Validation DataLoader 0:  60%|█████████▌      | 184/308 [00:41<00:28,  4.42it/s]
# Validation DataLoader 0:  60%|█████████▌      | 185/308 [00:41<00:27,  4.42it/s]
# Validation DataLoader 0:  60%|█████████▋      | 186/308 [00:42<00:27,  4.42it/s]
# Validation DataLoader 0:  61%|█████████▋      | 187/308 [00:42<00:27,  4.42it/s]
# Validation DataLoader 0:  61%|█████████▊      | 188/308 [00:42<00:27,  4.42it/s]
# Validation DataLoader 0:  61%|█████████▊      | 189/308 [00:42<00:26,  4.42it/s]
# Validation DataLoader 0:  62%|█████████▊      | 190/308 [00:42<00:26,  4.42it/s]
# Validation DataLoader 0:  62%|█████████▉      | 191/308 [00:43<00:26,  4.42it/s]
# Validation DataLoader 0:  62%|█████████▉      | 192/308 [00:43<00:26,  4.42it/s]
# Validation DataLoader 0:  63%|██████████      | 193/308 [00:43<00:26,  4.42it/s]
# Validation DataLoader 0:  63%|██████████      | 194/308 [00:43<00:25,  4.42it/s]
# Validation DataLoader 0:  63%|██████████▏     | 195/308 [00:44<00:25,  4.42it/s]
# Validation DataLoader 0:  64%|██████████▏     | 196/308 [00:44<00:25,  4.42it/s]
# Validation DataLoader 0:  64%|██████████▏     | 197/308 [00:44<00:25,  4.42it/s]
# Validation DataLoader 0:  64%|██████████▎     | 198/308 [00:44<00:24,  4.42it/s]
# Validation DataLoader 0:  65%|██████████▎     | 199/308 [00:45<00:24,  4.42it/s]
# Validation DataLoader 0:  65%|██████████▍     | 200/308 [00:45<00:24,  4.42it/s]
# Validation DataLoader 0:  65%|██████████▍     | 201/308 [00:45<00:24,  4.42it/s]
# Validation DataLoader 0:  66%|██████████▍     | 202/308 [00:45<00:24,  4.42it/s]
# Validation DataLoader 0:  66%|██████████▌     | 203/308 [00:45<00:23,  4.42it/s]
# Validation DataLoader 0:  66%|██████████▌     | 204/308 [00:46<00:23,  4.41it/s]
# Validation DataLoader 0:  67%|██████████▋     | 205/308 [00:46<00:23,  4.41it/s]
# Validation DataLoader 0:  67%|██████████▋     | 206/308 [00:46<00:23,  4.41it/s]
# Validation DataLoader 0:  67%|██████████▊     | 207/308 [00:46<00:22,  4.42it/s]
# Validation DataLoader 0:  68%|██████████▊     | 208/308 [00:46<00:22,  4.43it/s]
# Validation DataLoader 0:  68%|██████████▊     | 209/308 [00:47<00:22,  4.44it/s]
# Validation DataLoader 0:  68%|██████████▉     | 210/308 [00:47<00:21,  4.45it/s]
# Validation DataLoader 0:  69%|██████████▉     | 211/308 [00:47<00:21,  4.46it/s]
# Validation DataLoader 0:  69%|███████████     | 212/308 [00:47<00:21,  4.46it/s]
# Validation DataLoader 0:  69%|███████████     | 213/308 [00:47<00:21,  4.46it/s]
# Validation DataLoader 0:  69%|███████████     | 214/308 [00:47<00:21,  4.46it/s]
# Validation DataLoader 0:  70%|███████████▏    | 215/308 [00:48<00:20,  4.46it/s]
# Validation DataLoader 0:  70%|███████████▏    | 216/308 [00:48<00:20,  4.46it/s]
# Validation DataLoader 0:  70%|███████████▎    | 217/308 [00:48<00:20,  4.46it/s]
# Validation DataLoader 0:  71%|███████████▎    | 218/308 [00:48<00:20,  4.47it/s]
# Validation DataLoader 0:  71%|███████████▍    | 219/308 [00:48<00:19,  4.47it/s]
# Validation DataLoader 0:  71%|███████████▍    | 220/308 [00:49<00:19,  4.48it/s]
# Validation DataLoader 0:  72%|███████████▍    | 221/308 [00:49<00:19,  4.48it/s]
# Validation DataLoader 0:  72%|███████████▌    | 222/308 [00:49<00:19,  4.48it/s]
# Validation DataLoader 0:  72%|███████████▌    | 223/308 [00:49<00:18,  4.47it/s]
# Validation DataLoader 0:  73%|███████████▋    | 224/308 [00:50<00:18,  4.47it/s]
# Validation DataLoader 0:  73%|███████████▋    | 225/308 [00:50<00:18,  4.47it/s]
# Validation DataLoader 0:  73%|███████████▋    | 226/308 [00:50<00:18,  4.47it/s]
# Validation DataLoader 0:  74%|███████████▊    | 227/308 [00:50<00:18,  4.47it/s]
# Validation DataLoader 0:  74%|███████████▊    | 228/308 [00:51<00:17,  4.47it/s]
# Validation DataLoader 0:  74%|███████████▉    | 229/308 [00:51<00:17,  4.47it/s]
# Validation DataLoader 0:  75%|███████████▉    | 230/308 [00:51<00:17,  4.47it/s]
# Validation DataLoader 0:  75%|████████████    | 231/308 [00:51<00:17,  4.47it/s]
# Validation DataLoader 0:  75%|████████████    | 232/308 [00:51<00:17,  4.47it/s]
# Validation DataLoader 0:  76%|████████████    | 233/308 [00:52<00:16,  4.47it/s]
# Validation DataLoader 0:  76%|████████████▏   | 234/308 [00:52<00:16,  4.47it/s]
# Validation DataLoader 0:  76%|████████████▏   | 235/308 [00:52<00:16,  4.47it/s]
# Validation DataLoader 0:  77%|████████████▎   | 236/308 [00:52<00:16,  4.47it/s]
# Validation DataLoader 0:  77%|████████████▎   | 237/308 [00:53<00:15,  4.46it/s]
# Validation DataLoader 0:  77%|████████████▎   | 238/308 [00:53<00:15,  4.46it/s]
# Validation DataLoader 0:  78%|████████████▍   | 239/308 [00:53<00:15,  4.46it/s]
# Validation DataLoader 0:  78%|████████████▍   | 240/308 [00:53<00:15,  4.46it/s]
# Validation DataLoader 0:  78%|████████████▌   | 241/308 [00:54<00:15,  4.46it/s]
# Validation DataLoader 0:  79%|████████████▌   | 242/308 [00:54<00:14,  4.46it/s]
# Validation DataLoader 0:  79%|████████████▌   | 243/308 [00:54<00:14,  4.46it/s]
# Validation DataLoader 0:  79%|████████████▋   | 244/308 [00:54<00:14,  4.46it/s]
# Validation DataLoader 0:  80%|████████████▋   | 245/308 [00:54<00:14,  4.46it/s]
# Validation DataLoader 0:  80%|████████████▊   | 246/308 [00:55<00:13,  4.46it/s]
# Validation DataLoader 0:  80%|████████████▊   | 247/308 [00:55<00:13,  4.46it/s]
# Validation DataLoader 0:  81%|████████████▉   | 248/308 [00:55<00:13,  4.46it/s]
# Validation DataLoader 0:  81%|████████████▉   | 249/308 [00:55<00:13,  4.46it/s]
# Validation DataLoader 0:  81%|████████████▉   | 250/308 [00:56<00:13,  4.46it/s]
# Validation DataLoader 0:  81%|█████████████   | 251/308 [00:56<00:12,  4.46it/s]
# Validation DataLoader 0:  82%|█████████████   | 252/308 [00:56<00:12,  4.46it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 253/308 [00:56<00:12,  4.46it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 254/308 [00:56<00:12,  4.47it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 255/308 [00:56<00:11,  4.47it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 256/308 [00:57<00:11,  4.48it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 257/308 [00:57<00:11,  4.48it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 258/308 [00:57<00:11,  4.48it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 259/308 [00:57<00:10,  4.48it/s]
# Validation DataLoader 0:  84%|█████████████▌  | 260/308 [00:58<00:10,  4.48it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 261/308 [00:58<00:10,  4.47it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 262/308 [00:58<00:10,  4.47it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 263/308 [00:58<00:10,  4.47it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 264/308 [00:59<00:09,  4.47it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 265/308 [00:59<00:09,  4.47it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 266/308 [00:59<00:09,  4.47it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 267/308 [00:59<00:09,  4.47it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 268/308 [00:59<00:08,  4.47it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 269/308 [01:00<00:08,  4.47it/s]
# Validation DataLoader 0:  88%|██████████████  | 270/308 [01:00<00:08,  4.47it/s]
# Validation DataLoader 0:  88%|██████████████  | 271/308 [01:00<00:08,  4.47it/s]
# Validation DataLoader 0:  88%|██████████████▏ | 272/308 [01:00<00:08,  4.47it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 273/308 [01:01<00:07,  4.47it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 274/308 [01:01<00:07,  4.47it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 275/308 [01:01<00:07,  4.48it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 276/308 [01:01<00:07,  4.48it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 277/308 [01:01<00:06,  4.47it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 278/308 [01:02<00:06,  4.47it/s]
# Validation DataLoader 0:  91%|██████████████▍ | 279/308 [01:02<00:06,  4.47it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 280/308 [01:02<00:06,  4.47it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 281/308 [01:02<00:06,  4.47it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 282/308 [01:03<00:05,  4.47it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 283/308 [01:03<00:05,  4.47it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 284/308 [01:03<00:05,  4.47it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 285/308 [01:03<00:05,  4.47it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 286/308 [01:03<00:04,  4.47it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 287/308 [01:04<00:04,  4.47it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 288/308 [01:04<00:04,  4.47it/s]
# Validation DataLoader 0:  94%|███████████████ | 289/308 [01:04<00:04,  4.47it/s]
# Validation DataLoader 0:  94%|███████████████ | 290/308 [01:04<00:04,  4.47it/s]
# Validation DataLoader 0:  94%|███████████████ | 291/308 [01:05<00:03,  4.47it/s]
# Validation DataLoader 0:  95%|███████████████▏| 292/308 [01:05<00:03,  4.47it/s]
# Validation DataLoader 0:  95%|███████████████▏| 293/308 [01:05<00:03,  4.47it/s]
# Validation DataLoader 0:  95%|███████████████▎| 294/308 [01:05<00:03,  4.47it/s]
# Validation DataLoader 0:  96%|███████████████▎| 295/308 [01:06<00:02,  4.47it/s]
# Validation DataLoader 0:  96%|███████████████▍| 296/308 [01:06<00:02,  4.47it/s]
# Validation DataLoader 0:  96%|███████████████▍| 297/308 [01:06<00:02,  4.47it/s]
# Validation DataLoader 0:  97%|███████████████▍| 298/308 [01:06<00:02,  4.47it/s]
# Validation DataLoader 0:  97%|███████████████▌| 299/308 [01:06<00:02,  4.47it/s]
# Validation DataLoader 0:  97%|███████████████▌| 300/308 [01:07<00:01,  4.47it/s]
# Validation DataLoader 0:  98%|███████████████▋| 301/308 [01:07<00:01,  4.48it/s]
# Validation DataLoader 0:  98%|███████████████▋| 302/308 [01:07<00:01,  4.48it/s]
# Validation DataLoader 0:  98%|███████████████▋| 303/308 [01:07<00:01,  4.48it/s]
# Validation DataLoader 0:  99%|███████████████▊| 304/308 [01:07<00:00,  4.48it/s]
# Validation DataLoader 0:  99%|███████████████▊| 305/308 [01:08<00:00,  4.48it/s]
# Validation DataLoader 0:  99%|███████████████▉| 306/308 [01:08<00:00,  4.48it/s]
# Validation DataLoader 0: 100%|███████████████▉| 307/308 [01:08<00:00,  4.48it/s]
# Validation DataLoader 0: 100%|████████████████| 308/308 [01:08<00:00,  4.48it/s]
# Epoch 2: 100%|█| 2971/2971 [37:01<00:00,  1.34it/s, v_num=0, train_loss_step=1.2`Trainer.fit` stopped: `max_epochs=3` reached.
# Epoch 2: 100%|█| 2971/2971 [37:47<00:00,  1.31it/s, v_num=0, train_loss_step=1.2
